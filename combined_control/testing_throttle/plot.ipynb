# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("throttle_data_with_speed_ex4.csv")

# %%
df
# Out:
#      Time (ms)  Out1 (V)  Out2 (V)  Mode  Raw Value  Filtered Value  \
# 0     106504.0       1.0       0.5  ADAS      153.0          151.94
# 1     106604.0       1.0       0.5  ADAS      152.0          152.07
# 2     106704.0       1.0       0.5  ADAS      154.0          152.23
# 3     106804.0       1.0       0.5  ADAS      151.0          152.39
# 4     106904.0       1.0       0.5  ADAS      152.0          152.43
# ..         ...       ...       ...   ...        ...             ...
# 388   145452.0       1.0       0.5  ADAS      207.0          208.35
# 389   145552.0       1.0       0.5  ADAS      202.0          207.51
# 390   145652.0       1.0       0.5  ADAS      206.0          206.64
# 391   145752.0       1.0       0.5  ADAS      197.0          205.68
# 392   145852.0       1.0       0.5  ADAS      152.0          203.02
#
#      Pedal Percentage  Speed (KPH)
# 0                 1.0     0.000000
# 1                 1.0     0.000000
# 2                 1.0     0.000000
# 3                 1.0     0.000000
# 4                 1.0     0.000000
# ..                ...          ...
# 388              11.0     6.783765
# 389              10.0     6.783765
# 390              10.0     6.783765
# 391              10.0     6.710579
# 392              10.0     6.637348
#
# [393 rows x 8 columns]

# %%
df['Time (ms)'] = df['Time (ms)'] - df['Time (ms)'].iloc[0]

# %%
df
# Out:
#      Time (ms)  Out1 (V)  Out2 (V)  Mode  Raw Value  Filtered Value  \
# 0          0.0       1.0       0.5  ADAS      153.0          151.94
# 1        100.0       1.0       0.5  ADAS      152.0          152.07
# 2        200.0       1.0       0.5  ADAS      154.0          152.23
# 3        300.0       1.0       0.5  ADAS      151.0          152.39
# 4        400.0       1.0       0.5  ADAS      152.0          152.43
# ..         ...       ...       ...   ...        ...             ...
# 388    38948.0       1.0       0.5  ADAS      207.0          208.35
# 389    39048.0       1.0       0.5  ADAS      202.0          207.51
# 390    39148.0       1.0       0.5  ADAS      206.0          206.64
# 391    39248.0       1.0       0.5  ADAS      197.0          205.68
# 392    39348.0       1.0       0.5  ADAS      152.0          203.02
#
#      Pedal Percentage  Speed (KPH)
# 0                 1.0     0.000000
# 1                 1.0     0.000000
# 2                 1.0     0.000000
# 3                 1.0     0.000000
# 4                 1.0     0.000000
# ..                ...          ...
# 388              11.0     6.783765
# 389              10.0     6.783765
# 390              10.0     6.783765
# 391              10.0     6.710579
# 392              10.0     6.637348
#
# [393 rows x 8 columns]

# %%
df.to_csv("throttle_data_with_speed_ex4.csv", index=False)

# %% [markdown]
# ## Throttle Response

# %%
df = pd.read_csv("throttle_data_with_speed_ex4.csv")
df
# Out:
#      Time (ms)  Out1 (V)  Out2 (V)  Mode  Raw Value  Filtered Value  \
# 0          0.0       1.0       0.5  ADAS      153.0          151.94
# 1        100.0       1.0       0.5  ADAS      152.0          152.07
# 2        200.0       1.0       0.5  ADAS      154.0          152.23
# 3        300.0       1.0       0.5  ADAS      151.0          152.39
# 4        400.0       1.0       0.5  ADAS      152.0          152.43
# ..         ...       ...       ...   ...        ...             ...
# 388    38948.0       1.0       0.5  ADAS      207.0          208.35
# 389    39048.0       1.0       0.5  ADAS      202.0          207.51
# 390    39148.0       1.0       0.5  ADAS      206.0          206.64
# 391    39248.0       1.0       0.5  ADAS      197.0          205.68
# 392    39348.0       1.0       0.5  ADAS      152.0          203.02
#
#      Pedal Percentage  Speed (KPH)
# 0                 1.0     0.000000
# 1                 1.0     0.000000
# 2                 1.0     0.000000
# 3                 1.0     0.000000
# 4                 1.0     0.000000
# ..                ...          ...
# 388              11.0     6.783765
# 389              10.0     6.783765
# 390              10.0     6.783765
# 391              10.0     6.710579
# 392              10.0     6.637348
#
# [393 rows x 8 columns]

# %%
# Convert Brake State to numerical values (1 for RELEASED, 0 for APPLIED)
df['Mode Numerical'] = df['Mode'].apply(lambda x: 1 if x == 'ADAS' else 0)
df
# Out:
#      Time (ms)  Out1 (V)  Out2 (V)  Mode  Raw Value  Filtered Value  \
# 0          0.0       1.0       0.5  ADAS      153.0          151.94
# 1        100.0       1.0       0.5  ADAS      152.0          152.07
# 2        200.0       1.0       0.5  ADAS      154.0          152.23
# 3        300.0       1.0       0.5  ADAS      151.0          152.39
# 4        400.0       1.0       0.5  ADAS      152.0          152.43
# ..         ...       ...       ...   ...        ...             ...
# 388    38948.0       1.0       0.5  ADAS      207.0          208.35
# 389    39048.0       1.0       0.5  ADAS      202.0          207.51
# 390    39148.0       1.0       0.5  ADAS      206.0          206.64
# 391    39248.0       1.0       0.5  ADAS      197.0          205.68
# 392    39348.0       1.0       0.5  ADAS      152.0          203.02
#
#      Pedal Percentage  Speed (KPH)  Mode Numerical
# 0                 1.0     0.000000               1
# 1                 1.0     0.000000               1
# 2                 1.0     0.000000               1
# 3                 1.0     0.000000               1
# 4                 1.0     0.000000               1
# ..                ...          ...             ...
# 388              11.0     6.783765               1
# 389              10.0     6.783765               1
# 390              10.0     6.783765               1
# 391              10.0     6.710579               1
# 392              10.0     6.637348               1
#
# [393 rows x 9 columns]

# %%
# Create the plot
fig, ax1 = plt.subplots()
# Set the figure size
fig.set_size_inches(10*1.5, 6*1.5)

# Plot Raw Distance and Filtered Distance on the primary y-axis
ax1.plot(df['Time (ms)'], df['Speed (KPH)'] , label='Speed (KPH)', color='blue')
# ax1.plot(df['Time (ms)'], df['Raw Value'], label='Raw Value', color='orange')
ax1.set_xlabel('Time (ms)')
ax1.set_ylabel('Analog Value', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='lower left')

# Create a secondary y-axis for Brake State
ax2 = ax1.twinx()
ax2.step(df['Time (ms)'], df['Mode Numerical'], label='State (1=ADAS, 0=Manual)', color='green', where='post')
ax2.set_ylabel('Mode', color='green')
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylim(-0.1, 1.1)  # Set limits to make the step plot clearer
ax2.legend(loc='upper left')

# Show the plot
plt.title('Analog Value over Time')
plt.show()

# %%
# Subset the data from index 75 to 84
fig, ax = plt.subplots()
df_subset = df.iloc[95:105]  # This is already done in your code

# Plot Raw Distance
ax.plot(df_subset['Time (ms)'], df_subset['Speed (KPH)'], label='Speed (KPH)', color='blue')

# Add dots at index 75 and 84
ax.scatter(df_subset['Time (ms)'].iloc[4], df_subset['Speed (KPH)'].iloc[4], color='red', s=100, label='Index 75')
ax.scatter(df_subset['Time (ms)'].iloc[-5], df_subset['Speed (KPH)'].iloc[-5], color='green', s=100, label='Index 84')

# Set labels for the primary y-axis
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Speed (KPH)', color='blue')
ax.tick_params(axis='y', labelcolor='blue')

# Add title
# Extract and print the exact time at index 75 and 84
time_at_75 = df_subset['Time (ms)'].iloc[4]
time_at_84 = df_subset['Time (ms)'].iloc[-5]
plt.title(f"ECU vs Speed (KPH)")
# Add the time difference text below the figure
plt.figtext(0.5, -0.05, f"Time needed vehicle to response: {time_at_84 - time_at_75} ms", ha='center', fontsize=12)
# Show the plot
plt.show()

# %% [markdown]
# ## SPEED 10 KPH

# %%
df = pd.read_csv("brake_data_with_speed10.csv")
df
# Out:
#      Time (ms)  Raw Distance (mm)  Filtered Distance (mm)  Speed (KPH)  \
# 0          0.0               53.0                   53.04     1.230814
# 1        107.0               55.0                   53.03     1.230814
# 2        214.0               60.0                   53.11     1.230814
# 3        321.0               59.0                   53.34     1.230814
# 4        428.0               60.0                   53.71     1.230814
# ..         ...                ...                     ...          ...
# 100    10733.0              108.0                   70.50     0.000000
# 101    10840.0              110.0                   76.99     0.000000
# 102    10947.0              106.0                   82.94     1.307371
# 103    11054.0              109.0                   88.28     1.447606
# 104    11161.0              110.0                   93.00     1.664028
#
#     Brake State
# 0      RELEASED
# 1      RELEASED
# 2      RELEASED
# 3      RELEASED
# 4      RELEASED
# ..          ...
# 100    RELEASED
# 101    RELEASED
# 102    RELEASED
# 103    RELEASED
# 104    RELEASED
#
# [105 rows x 5 columns]

# %%
# Convert Brake State to numerical values (1 for RELEASED, 0 for APPLIED)
df['Brake State Numerical'] = df['Brake State'].apply(lambda x: 1 if x == 'RELEASED' else 0)
df
# Out:
#      Time (ms)  Raw Distance (mm)  Filtered Distance (mm)  Speed (KPH)  \
# 0          0.0               53.0                   53.04     1.230814
# 1        107.0               55.0                   53.03     1.230814
# 2        214.0               60.0                   53.11     1.230814
# 3        321.0               59.0                   53.34     1.230814
# 4        428.0               60.0                   53.71     1.230814
# ..         ...                ...                     ...          ...
# 100    10733.0              108.0                   70.50     0.000000
# 101    10840.0              110.0                   76.99     0.000000
# 102    10947.0              106.0                   82.94     1.307371
# 103    11054.0              109.0                   88.28     1.447606
# 104    11161.0              110.0                   93.00     1.664028
#
#     Brake State  Brake State Numerical
# 0      RELEASED                      1
# 1      RELEASED                      1
# 2      RELEASED                      1
# 3      RELEASED                      1
# 4      RELEASED                      1
# ..          ...                    ...
# 100    RELEASED                      1
# 101    RELEASED                      1
# 102    RELEASED                      1
# 103    RELEASED                      1
# 104    RELEASED                      1
#
# [105 rows x 6 columns]

# %%
# Create the plot
fig, ax1 = plt.subplots()
# Set the figure size
fig.set_size_inches(10*1.5, 6*1.5)

# Plot Raw Distance and Filtered Distance on the primary y-axis
ax1.plot(df['Time (ms)'], df['Raw Distance (mm)'], label='Raw Distance (mm)', color='blue')
ax1.plot(df['Time (ms)'], df['Filtered Distance (mm)'], label='Filtered Distance (mm)', color='orange')
ax1.set_xlabel('Time (ms)')
ax1.set_ylabel('Distance (mm)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='lower left')

# Create a secondary y-axis for Brake State
ax2 = ax1.twinx()
ax2.step(df['Time (ms)'], df['Brake State Numerical'], label='Brake State (1=RELEASED, 0=APPLIED)', color='green', where='post')
ax2.set_ylabel('Brake State', color='green')
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylim(-0.1, 1.1)  # Set limits to make the step plot clearer
ax2.legend(loc='upper left')

# Show the plot
plt.title('Distance and Brake State over Time')
plt.show()

# %%
# Subset the data from index 75 to 84
fig, ax = plt.subplots()
df_subset = df.iloc[55:75]  # This is already done in your code

# Plot Raw Distance
ax.plot(df_subset['Time (ms)'], df_subset['Raw Distance (mm)'], label='Raw Distance (mm)', color='blue')

# Add dots at index 75 and 84
ax.scatter(df_subset['Time (ms)'].iloc[7], df_subset['Raw Distance (mm)'].iloc[7], color='red', s=100, label='Index 75')
ax.scatter(df_subset['Time (ms)'].iloc[-1], df_subset['Raw Distance (mm)'].iloc[-1], color='green', s=100, label='Index 84')

# Set labels for the primary y-axis
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Distance (mm)', color='blue')
ax.tick_params(axis='y', labelcolor='blue')

# Add title
# Extract and print the exact time at index 75 and 84
time_at_75 = df_subset['Time (ms)'].iloc[7]
time_at_84 = df_subset['Time (ms)'].iloc[-1]
plt.title(f"Pedal Position vs Time at Vehicle Stop")
# Add the time difference text below the figure
plt.figtext(0.5, -0.05, f"Time needed for brake to go from 0 to 100%: {time_at_84 - time_at_75} ms", ha='center', fontsize=12)
# Show the plot
plt.show()

# %% [markdown]
# ## SPEED 40 KPH

# %%
df = pd.read_csv("brake_data_with_speed40.csv")

# %%
df
# Out:
#      Time (ms)  Raw Distance (mm)  Filtered Distance (mm)  Brake Position (%)  \
# 0          0.0               58.0                   55.40                 0.0
# 1        107.0               55.0                   55.64                 0.0
# 2        214.0               54.0                   55.81                 0.0
# 3        321.0               53.0                   55.89                 0.0
# 4        428.0               55.0                   55.88                 0.0
# ..         ...                ...                     ...                 ...
# 164    17593.0               99.0                   88.95                 0.0
# 165    17700.0              101.0                   91.59                 0.0
# 166    17807.0              106.0                   93.92                 0.0
# 167    17914.0              103.0                   96.03                 0.0
# 168    18021.0              104.0                   97.89                 0.0
#
#      Speed (KPH) Brake State
# 0       3.444799    RELEASED
# 1       3.444799    RELEASED
# 2       3.444799    RELEASED
# 3       3.444799    RELEASED
# 4       3.444799    RELEASED
# ..           ...         ...
# 164     0.000000    RELEASED
# 165     0.000000    RELEASED
# 166     0.000000    RELEASED
# 167     0.000000    RELEASED
# 168     0.000000    RELEASED
#
# [169 rows x 6 columns]

# %%
# Convert Brake State to numerical values (1 for RELEASED, 0 for APPLIED)
df['Brake State Numerical'] = df['Brake State'].apply(lambda x: 1 if x == 'RELEASED' else 0)
df
# Out:
#      Time (ms)  Raw Distance (mm)  Filtered Distance (mm)  Brake Position (%)  \
# 0          0.0               58.0                   55.40                 0.0
# 1        107.0               55.0                   55.64                 0.0
# 2        214.0               54.0                   55.81                 0.0
# 3        321.0               53.0                   55.89                 0.0
# 4        428.0               55.0                   55.88                 0.0
# ..         ...                ...                     ...                 ...
# 164    17593.0               99.0                   88.95                 0.0
# 165    17700.0              101.0                   91.59                 0.0
# 166    17807.0              106.0                   93.92                 0.0
# 167    17914.0              103.0                   96.03                 0.0
# 168    18021.0              104.0                   97.89                 0.0
#
#      Speed (KPH) Brake State  Brake State Numerical
# 0       3.444799    RELEASED                      1
# 1       3.444799    RELEASED                      1
# 2       3.444799    RELEASED                      1
# 3       3.444799    RELEASED                      1
# 4       3.444799    RELEASED                      1
# ..           ...         ...                    ...
# 164     0.000000    RELEASED                      1
# 165     0.000000    RELEASED                      1
# 166     0.000000    RELEASED                      1
# 167     0.000000    RELEASED                      1
# 168     0.000000    RELEASED                      1
#
# [169 rows x 7 columns]

# %%
df.drop(columns=['Brake Position (%)'], inplace=True)
df.to_csv("brake_data_with_speed40.csv", index=False)

# %% [markdown]
# ### Read

# %%
df = pd.read_csv("brake_data_with_speed40.csv")
df
# Out:
#      Time (ms)  Raw Distance (mm)  Filtered Distance (mm)  Speed (KPH)  \
# 0          0.0               58.0                   55.40     3.444799
# 1        107.0               55.0                   55.64     3.444799
# 2        214.0               54.0                   55.81     3.444799
# 3        321.0               53.0                   55.89     3.444799
# 4        428.0               55.0                   55.88     3.444799
# ..         ...                ...                     ...          ...
# 164    17593.0               99.0                   88.95     0.000000
# 165    17700.0              101.0                   91.59     0.000000
# 166    17807.0              106.0                   93.92     0.000000
# 167    17914.0              103.0                   96.03     0.000000
# 168    18021.0              104.0                   97.89     0.000000
#
#     Brake State  Brake State Numerical
# 0      RELEASED                      1
# 1      RELEASED                      1
# 2      RELEASED                      1
# 3      RELEASED                      1
# 4      RELEASED                      1
# ..          ...                    ...
# 164    RELEASED                      1
# 165    RELEASED                      1
# 166    RELEASED                      1
# 167    RELEASED                      1
# 168    RELEASED                      1
#
# [169 rows x 6 columns]

# %%
# Create the plot
fig, ax1 = plt.subplots()
# Set the figure size
fig.set_size_inches(10*1.5, 6*1.5)

# Plot Raw Distance and Filtered Distance on the primary y-axis
ax1.plot(df['Time (ms)'], df['Raw Distance (mm)'], label='Raw Distance (mm)', color='blue')
ax1.plot(df['Time (ms)'], df['Filtered Distance (mm)'], label='Filtered Distance (mm)', color='orange')
ax1.set_xlabel('Time (ms)')
ax1.set_ylabel('Distance (mm)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='lower left')

# Create a secondary y-axis for Brake State
ax2 = ax1.twinx()
ax2.step(df['Time (ms)'], df['Brake State Numerical'], label='Brake State (1=RELEASED, 0=APPLIED)', color='green', where='post')
ax2.set_ylabel('Brake State', color='green')
ax2.tick_params(axis='y', labelcolor='green')
ax2.set_ylim(-0.1, 1.1)  # Set limits to make the step plot clearer
ax2.legend(loc='upper left')

# Show the plot
plt.title('Distance and Brake State over Time')
plt.show()

# %%
# Subset the data from index 75 to 84
fig, ax = plt.subplots()
df_subset = df.iloc[70:90]  # This is already done in your code

# Plot Raw Distance
ax.plot(df_subset['Time (ms)'], df_subset['Raw Distance (mm)'], label='Raw Distance (mm)', color='blue')

# Add dots at index 75 and 84
ax.scatter(df_subset['Time (ms)'].iloc[5], df_subset['Raw Distance (mm)'].iloc[5], color='red', s=100, label='Index 75')
ax.scatter(df_subset['Time (ms)'].iloc[-6], df_subset['Raw Distance (mm)'].iloc[-6], color='green', s=100, label='Index 84')

# Set labels for the primary y-axis
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Distance (mm)', color='blue')
ax.tick_params(axis='y', labelcolor='blue')

# Add title
# Extract and print the exact time at index 75 and 84
time_at_75 = df_subset['Time (ms)'].iloc[5]
time_at_84 = df_subset['Time (ms)'].iloc[-6]
plt.title(f"Pedal Position vs Time at Velocity 40 km/h")
# Add the time difference text below the figure
plt.figtext(0.5, -0.05, f"Time needed for brake to go from 0 to 100%: {time_at_84 - time_at_75} ms", ha='center', fontsize=12)
# Show the plot
plt.show()

# %% [markdown]
# ## STOP
