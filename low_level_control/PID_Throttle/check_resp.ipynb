# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/irman/Documents/ADAS-Brio/low_level_control/PID_Throttle/speed_control_data_20241115-112841.csv")
df
# Out:
#         Time  Desired_Speed  Actual_Speed  Throttle_Output  Brake_Output
# 0      0.035            0.0          4.77              0.0          4.77
# 1      0.054            0.0          4.63              0.0          4.63
# 2      0.075            0.0          4.49              0.0          4.49
# 3      0.094            0.0          4.28              0.0          4.28
# 4      0.133            0.0          4.14              0.0          4.14
# ...      ...            ...           ...              ...           ...
# 1202  29.901            0.0          3.86              0.0          3.86
# 1203  29.941            0.0          3.86              0.0          3.86
# 1204  29.959            0.0          3.86              0.0          3.86
# 1205  29.979            0.0          3.80              0.0          3.80
# 1206  30.018            0.0          3.80              0.0          3.80
#
# [1207 rows x 5 columns]

# %%
# plot actual vs desired speed
# plt.plot(df["Time"], df["Desired_Speed"])
plt.plot(df["Time"], df["Actual_Speed"])
plt.plot(df["Time"], df["Brake_Output"])
plt.ylim(0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs desired speed
plt.figure(figsize=(10, 6))
plt.plot(df["Time"], df["Desired_Speed"], label='Desired Speed', color='blue')
plt.plot(df["Time"], df["Actual_Speed"], label='Actual Speed', color='red')

# Set axis labels and title
plt.xlabel('Time (s)')
plt.ylabel('Speed (kph)')
plt.title('Speed Control Performance')

# Set y-axis to start from 0
plt.ylim(bottom=0)

# Add grid and legend
plt.grid(True)
plt.legend()

plt.show()
